# %% [markdown]
# #### Pandas Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv(r"D:\PowerBI\Ice Cream Ratings.csv")
df=df.set_index('Date')
df
# Out:
#           Flavor Rating  Texture Rating  Overall Rating
# Date
# 1/1/2022       0.223090        0.040220        0.600129
# 1/2/2022       0.635886        0.938476        0.106264
# 1/3/2022       0.442323        0.044154        0.598112
# 1/4/2022       0.389128        0.549676        0.489353
# 1/5/2022       0.386887        0.519439        0.988280
# 1/6/2022       0.877984        0.193588        0.832827
# 1/7/2022       0.140995        0.325110        0.105147

# %%
df['Texture Rating'].plot(title='Ice Cream Ratings',kind='bar',stacked=True)
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Date'>

# %%
df.plot(title='Ice Cream Ratings',kind='scatter',x="Texture Rating",y='Flavor Rating' ,stacked=True)
# Out:
# <Axes: title={'center': 'Ice Cream Ratings'}, xlabel='Texture Rating', ylabel='Flavor Rating'>

# %%
df.boxplot()
# Out:
# <Axes: >
